# %%
import pydicom

# %%
from pydicom.data import get_testdata_files

# %%
# %matplotlib inline
import numpy as np
from os.path import dirname, join
import matplotlib.pyplot as plt

import pydicom
from pydicom.data import get_testdata_files
from pydicom.filereader import read_dicomdir

dcm = pydicom.dcmread("../data/pelda2.dcm")
print(dcm)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '19970630'
# (0008, 0013) Instance Creation Time              TM: '170131'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.4320.5030.618853748224074515734894306203
# (0008, 0020) Study Date                          DA: '19970630'
# (0008, 0021) Series Date                         DA: '19970630'
# (0008, 0022) Acquisition Date                    DA: '19970630'
# (0008, 0023) Content Date                        DA: '19970630'
# (0008, 0030) Study Time                          TM: '165846.0000'
# (0008, 0031) Series Time                         TM: '170035.0000'
# (0008, 0032) Acquisition Time                    TM: '170054'
# (0008, 0033) Content Time                        TM: '170131'
# (0008, 0050) Accession Number                    SH: '7342211443283646'
# (0008, 0054) Retrieve AE Title                   AE: 'AE_TITLE'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ' '
# (0008, 1030) Study Description                   LO: 'Diagnostic Pre-Surgery Contrast Enhanced CT'
# (0008, 103e) Series Description                  LO: '= NONE ='
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed16'
# (0008, 2111) Derivation Description              ST: ''
# (0009, 0010) Private Creator                     LO: 'EMAGEON STUDY HOME'
# (0010, 0010) Patient's Name                      PN: 'R_004'
# (0010, 0020) Patient ID                          LO: 'R_004'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'O'
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence   7 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'LungCT-Diagnosis'
# (0013, 1013) Private tag data                    UN: b'43205030'
# (0018, 0015) Body Part Examined                  CS: 'LUNG'
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "5.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0081) Echo Time                           DS: None
# (0018, 0088) Spacing Between Slices              DS: None
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1020) Software Versions                   LO: '07MW11.10'
# (0018, 1030) Protocol Name                       LO: '5.1 CHEST'
# (0018, 1100) Reconstruction Diameter             DS: "425.0"
# (0018, 1110) Distance Source to Detector         DS: "949.075012"
# (0018, 1111) Distance Source to Patient          DS: "541.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "157.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "965"
# (0018, 1151) X-Ray Tube Current                  IS: "244"
# (0018, 1152) Exposure                            IS: "35"
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: "48000"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1210) Convolution Kernel                  SH: 'LUNG'
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0018, 5101) View Position                       CS: ''
# (0018, 9305) Revolution Time                     FD: 0.800000011920929
# (0018, 9306) Single Collimation Width            FD: 1.25
# (0018, 9307) Total Collimation Width             FD: 20.0
# (0018, 9309) Table Speed                         FD: 34.37499948777259
# (0018, 9310) Table Feed per Rotation             FD: 27.5
# (0018, 9311) Spiral Pitch Factor                 FD: 1.375
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.4320.5030.248552508121514040263344871813
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.4320.5030.966354075876482042295761929295
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "3"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "39"
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: [-209.400, -223.900, -186.750]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.4320.5030.310247373747695826584516880483
# (0020, 0060) Laterality                          CS: ''
# (0020, 1002) Images in Acquisition               IS: "0"
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-186.75"
# (0020, 4000) Image Comments                      LT: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.830078, 0.830078]
# (0028, 0034) Pixel Aspect Ratio                  IS: [0, 0]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          SS: 0
# (0028, 0107) Largest Image Pixel Value           SS: 0
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: "-670.0"
# (0028, 1051) Window Width                        DS: "1225.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 2110) Lossy Image Compression             CS: ''
# (0032, 000c) Study Priority ID                   CS: 'LOW'
# (0032, 1030) Reason for Study                    LO: ''
# (0032, 4000) Study Comments                      LT: ''
# (0040, 0244) Performed Procedure Step Start Date DA: '19970630'
# (0040, 0245) Performed Procedure Step Start Time TM: '165846'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'CHEST'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements

# %%
# i need these from the dicomheader to calculate HU as HU = grayvalue * slope + intercept
intercept = int(dcm.RescaleIntercept)
slope = int(dcm.RescaleSlope)
pixel_spacing = float(dcm.PixelSpacing[0])
mypixels = dcm.pixel_array * slope + intercept

# %%
plt.imshow(mypixels, cmap=plt.cm.bone)

# %%
# gaussian smoothing 
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.gaussian_filter.html
# TODO: how much sigma to use
from scipy.ndimage import gaussian_filter
mypixels = gaussian_filter(mypixels, sigma=pixel_spacing)
plt.imshow(mypixels,  cmap=plt.cm.bone )

# %%
plt.rcParams["figure.figsize"] = (20,10)
# gray level tresholding
# TODO: experiment with other than -500

mask = (mypixels > -500) | (mypixels < -980)
mypixels[mask] = -10000
plt.imshow(mypixels,  cmap=plt.cm.bone )

# %%
hstp = dcm.pixel_array * slope + intercept

# %%
hst = (hstp > -1500) & (hstp != -1024) & (hstp != -1000) 
hst = hstp[hst]

plt.hist(hst, bins=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-54e479bc0410> in <module>
# ----> 1 hst = (hstp > -1500) & (hstp != -1024) & (hstp != -1000)
#       2 hst = hstp[hst]
#       3
#       4 plt.hist(hst, bins=1000)
#       5 plt.show()
#
# NameError: name 'hstp' is not defined

# %%
# floodfill non-lung region
# ASK: should i implement this manually?
from skimage.morphology import flood_fill
filled = mypixels.copy()
xmax, ymax = filled.shape
i = 0


flood_fill(filled, (i, 0), -3000, tolerance=2500,connectivity=1, inplace=True) # int(ymax*0.15)
flood_fill(filled, (i, ymax-1), -3000, tolerance=2500,connectivity=1, inplace=True) # int(ymax*0.85)

flood_fill(filled, (xmax-1, ymax-1), -3000, tolerance=2500,connectivity=1, inplace=True) # int(xmax*0.85)
flood_fill(filled, (xmax-1, i), -3000, tolerance=2500,connectivity=1, inplace=True) # int(xmax*0.85)


    
filled[filled == -10000] = -1024
filled[filled == -3000] = -1024
#%matplotlib nbagg
plt.imshow(filled,  cmap=plt.cm.bone )
